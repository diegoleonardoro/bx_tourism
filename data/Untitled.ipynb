# %%
import json

with open('data.json') as json_file:
    data = json.load(json_file)

# %%
for d in data:
    print (d)
    print ("-"*100)
# Out:
# type
# ----------------------------------------------------------------------------------------------------
# features
# ----------------------------------------------------------------------------------------------------

# %%
for d in data["features"]:
    print (d.boro_name)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-12-c55cea9ddaa2> in <module>
#       1 for d in data["features"]:
# ----> 2     print (d.boro_name)
#
# AttributeError: 'dict' object has no attribute 'boro_name'

# %%
nuevo_dict = []

for d in data["features"]:
    if d["properties"]["boro_name"] == "Bronx":
        new_dict = d
        nuevo_dict.append (new_dict)
        print (new_dict)
        print ("-"*10000)
# Out:
# {'type': 'Feature', 'properties': {'ntacode': 'BX59', 'shape_area': '23945209.7754', 'county_fips': '005', 'ntaname': 'Westchester-Unionport', 'shape_leng': '26557.4093256', 'boro_name': 'Bronx', 'boro_code': '2'}, 'geometry': {'type': 'MultiPolygon', 'coordinates': [[[[-73.83936794316948, 40.840882972980125], [-73.83956700333053, 40.840547227887406], [-73.83972014449361, 40.83956540598519], [-73.84030282537185, 40.83952431394499], [-73.84027376887708, 40.83920627289514], [-73.84022375735445, 40.83913683912727], [-73.84016248431188, 40.83906606528612], [-73.84016698511662, 40.83900415346526], [-73.84014540732231, 40.83894399683767], [-73.84010873870926, 40.838852118208884], [-73.8400306359839, 40.83885759214779], [-73.8400444128228, 40.83894435352963], [-73.84002808869033, 40.83894787100795], [-73.84000970504766, 40.83883809045587], [-73.84009889636502, 40.838827455411284], [-73.84006879974, 40.83875204009078], [-73.84010742962913, 40.83862842890273], [-73.84013531533492, 40.83861417
# ...

# %%
nuevo_dict
# Out:
# [{'type': 'Feature',
#   'properties': {'ntacode': 'BX59',
#    'shape_area': '23945209.7754',
#    'county_fips': '005',
#    'ntaname': 'Westchester-Unionport',
#    'shape_leng': '26557.4093256',
#    'boro_name': 'Bronx',
#    'boro_code': '2'},
#   'geometry': {'type': 'MultiPolygon',
#    'coordinates': [[[[-73.83936794316948, 40.840882972980125],
#       [-73.83956700333053, 40.840547227887406],
#       [-73.83972014449361, 40.83956540598519],
#       [-73.84030282537185, 40.83952431394499],
#       [-73.84027376887708, 40.83920627289514],
#       [-73.84022375735445, 40.83913683912727],
#       [-73.84016248431188, 40.83906606528612],
#       [-73.84016698511662, 40.83900415346526],
#       [-73.84014540732231, 40.83894399683767],
#       [-73.84010873870926, 40.838852118208884],
#       [-73.8400306359839, 40.83885759214779],
#       [-73.8400444128228, 40.83894435352963],
#       [-73.84002808869033, 40.83894787100795],
#       [-73.84000970504766, 40.83883809045587],
# ...
